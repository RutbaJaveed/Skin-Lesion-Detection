# %%
import os

# Define paths to the image folders
part1_path = '/kaggle/input/dataset/HAM10000_images_part_1'
part2_path = '/kaggle/input/dataset/HAM10000_images_part_2'

# Count images in each part 
part1_count = len([
    f for f in os.listdir(part1_path)
    if os.path.isfile(os.path.join(part1_path, f)) and f.lower().endswith('.jpg')
])

part2_count = len([
    f for f in os.listdir(part2_path)
    if os.path.isfile(os.path.join(part2_path, f)) and f.lower().endswith('.jpg')
])

# Print the results
print(f"Images in part 1: {part1_count}")
print(f"Images in part 2: {part2_count}")
print(f"Total images: {part1_count + part2_count}")
# Out:
# Images in part 1: 5000
# Images in part 2: 5015
# Total images: 10015

# %%
import os
import shutil
import pandas as pd

# Define paths
metadata_file = '/kaggle/input/dataset/HAM10000_metadata.csv'
images_part1 = '/kaggle/input/dataset/HAM10000_images_part_1'
images_part2 = '/kaggle/input/dataset/HAM10000_images_part_2'
output_dir = '/kaggle/working/HAM10000_rearranged'

# Create output directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# Load metadata
df = pd.read_csv(metadata_file)

# Get unique classes (e.g., 'nv', 'mel', etc.)
classes = df['dx'].unique()

# Create class subdirectories
for cls in classes:
    os.makedirs(os.path.join(output_dir, cls), exist_ok=True)

# Function to find image file path
def find_image_path(image_id):
    filename = image_id + '.jpg'
    path1 = os.path.join(images_part1, filename)
    path2 = os.path.join(images_part2, filename)
    if os.path.exists(path1):
        return path1
    elif os.path.exists(path2):
        return path2
    else:
        return None

# Rearrange images into class folders
missing_images = []
for _, row in df.iterrows():
    image_id = row['image_id']
    label = row['dx']
    src_path = find_image_path(image_id)
    
    if src_path:
        dst_path = os.path.join(output_dir, label, image_id + '.jpg')
        shutil.copy2(src_path, dst_path)
    else:
        missing_images.append(image_id)

# Report missing images if any
print(f"Completed rearranging. {len(missing_images)} missing images were found.")
if missing_images:
    print("Missing image IDs:", missing_images[:5])  # Print a few missing image IDs
# Out:
# Completed rearranging. 0 missing images were found.

# %%
import os

# Path to your rearranged dataset folder 
dataset_dir = '/kaggle/working/HAM10000_rearranged'

# Loop through each class folder
for class_name in os.listdir(dataset_dir):
    class_path = os.path.join(dataset_dir, class_name)
    if os.path.isdir(class_path):
        num_images = len([
            f for f in os.listdir(class_path)
            if os.path.isfile(os.path.join(class_path, f)) and f.lower().endswith('.jpg')
        ])
        print(f"{class_name}: {num_images} images")
# Out:
# bcc: 514 images
# akiec: 327 images
# nv: 6705 images
# bkl: 1099 images
# vasc: 142 images
# mel: 1113 images
# df: 115 images

# %%
import os
import math
import random
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array, array_to_img

# Input and output directories
input_dir = "/kaggle/working/HAM10000_rearranged"
output_dir = "/kaggle/working/HAM10000_balanced_aug"
os.makedirs(output_dir, exist_ok=True)

# List of classes and target images per class
classes = ["akiec", "bcc", "bkl", "df", "mel", "nv", "vasc"]
target_count = 3000
target_size = (128, 128)  # Resize images to 128x128

# Define augmentation generator (for classes other than 'nv')
datagen = ImageDataGenerator(
    rotation_range=20,
    zoom_range=0.2,
    width_shift_range=0.2,
    height_shift_range=0.2,
    fill_mode='nearest'
)

for cls in classes:
    print(f"Processing class: {cls}")
    class_input_dir = os.path.join(input_dir, cls)
    class_output_dir = os.path.join(output_dir, cls)
    os.makedirs(class_output_dir, exist_ok=True)

    # Get list of image filenames 
    original_images = [f for f in os.listdir(class_input_dir) if f.lower().endswith(('.jpg'))]
    num_original = len(original_images)
    print(f"  Found {num_original} original images.")

    saved_count = 0  # counter for how many images saved in output

    if cls == "nv":
        # For nv, simply sample 3000 images from the original list (after resizing)
        if num_original < target_count:
            print(f"  Warning: {cls} has fewer than {target_count} images. Copying all available images.")
            selected = original_images
        else:
            selected = random.sample(original_images, target_count)

        for filename in selected:
            src_path = os.path.join(class_input_dir, filename)
            try:
                # Load, resize, and save the image
                img = load_img(src_path, target_size=target_size)
                dst_path = os.path.join(class_output_dir, filename)
                img.save(dst_path)
                saved_count += 1
            except Exception as e:
                print(f"  Error processing {src_path}: {e}")
        print(f"  Saved {saved_count} images for class '{cls}'.")

    else:
        # For other classes, we need to augment so that total images = target_count.
        # First, calculate how many augmented images are needed.
        needed = target_count - num_original
        # Compute how many augmentations per original image (at least)
        aug_per_image = math.ceil(needed / num_original)
        print(f"  Each original will produce {aug_per_image} augmented images (approximately).")

        # Loop over each original image
        for filename in original_images:
            if saved_count >= target_count:
                break  # Stop if we've reached target

            src_path = os.path.join(class_input_dir, filename)
            try:
                # Load and resize the original image
                img = load_img(src_path, target_size=target_size)
            except Exception as e:
                print(f"  Error loading {src_path}: {e}")
                continue

            # Save the resized original image (suffix with "orig_")
            base_name, ext = os.path.splitext(filename)
            out_name = f"{base_name}_orig{ext}"
            dst_path = os.path.join(class_output_dir, out_name)
            try:
                img.save(dst_path)
                saved_count += 1
            except Exception as e:
                print(f"  Error saving {dst_path}: {e}")
                continue

            # Convert image to array and reshape for augmentation
            x = img_to_array(img)
            x = x.reshape((1,) + x.shape)  # shape: (1, 128, 128, channels)

            # Generate augmented images using the datagen.flow generator.
            aug_iter = datagen.flow(x, batch_size=1)
            for i in range(aug_per_image):
                if saved_count >= target_count:
                    break
                # Generate one augmented image
                batch = next(aug_iter)
                aug_img = array_to_img(batch[0])
                aug_filename = f"{base_name}_aug{i}{ext}"
                aug_dst = os.path.join(class_output_dir, aug_filename)
                try:
                    aug_img.save(aug_dst)
                    saved_count += 1
                except Exception as e:
                    print(f"  Error saving {aug_dst}: {e}")
        print(f"  Total images saved for class '{cls}': {saved_count}")

    # If for some reason we exceeded target_count, we can report or adjust here.
    if saved_count < target_count:
        print(f"  Note: Only {saved_count} images were produced for class '{cls}' (target was {target_count}).")
    elif saved_count > target_count:
        print(f"  Note: Produced {saved_count} images for class '{cls}', which exceeds the target of {target_count}.")

print("Augmented balanced dataset creation complete.")
# Out:
# 2025-07-25 10:24:50.009332: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1753439090.242882      36 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1753439090.316305      36 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Processing class: akiec
#   Found 327 original images.
#   Each original will produce 9 augmented images (approximately).
#   Total images saved for class 'akiec': 3000
# Processing class: bcc
#   Found 514 original images.
#   Each original will produce 5 augmented images (approximately).
#   Total images saved for class 'bcc': 3000
# Processing class: bkl
#   Found 1099 original images.
#   Each original will produce 2 augmented images (approximately).
#   Total images saved for class 'bkl': 3000
# Processing class: df
#   Found 115 original images.
#   Each original will produce 26 augmented images (approximately).
#   Total images saved for class 'df': 3000
# Processing class: mel
#   Found 1113 original images.
#   Each original will produce 2 augmented images (approximately).
#   Total images saved for class 'mel': 3000
# Processing class: nv
#   Found 6705 original images.
#   Saved 3000 images for class 'nv'.
# Processing class: vasc
#   Found 142 original images.
#   Each original will produce 21 augmented images (approximately).
#   Total images saved for class 'vasc': 3000
# Augmented balanced dataset creation complete.

# %%
import os

# Path to the rearranged dataset
rearranged_dir = "/kaggle/working/HAM10000_balanced_aug"

# Count images in each class folder
for class_name in sorted(os.listdir(rearranged_dir)):
    class_path = os.path.join(rearranged_dir, class_name)
    if os.path.isdir(class_path):  # Ensure it's a folder
        num_images = len([img for img in os.listdir(class_path) if img.endswith('.jpg')])
        print(f"{class_name}: {num_images} images")
# Out:
# akiec: 3000 images
# bcc: 3000 images
# bkl: 3000 images
# df: 3000 images
# mel: 3000 images
# nv: 3000 images
# vasc: 3000 images

# %%
import os
import random
import shutil

# Set input and output directories
input_dir = "/kaggle/working/HAM10000_balanced_aug"
output_dir = "/kaggle/working/HAM10000_split"
os.makedirs(output_dir, exist_ok=True)

# Define subdirectories for training, validation, and testing
train_dir = os.path.join(output_dir, "train")
val_dir = os.path.join(output_dir, "val")
test_dir = os.path.join(output_dir, "test")
os.makedirs(train_dir, exist_ok=True)
os.makedirs(val_dir, exist_ok=True)
os.makedirs(test_dir, exist_ok=True)

# List the class directories (each class should be a subfolder in input_dir)
classes = [d for d in os.listdir(input_dir) if os.path.isdir(os.path.join(input_dir, d))]

for cls in classes:
    cls_input_dir = os.path.join(input_dir, cls)

    # Create corresponding output directories for this class
    cls_train_dir = os.path.join(train_dir, cls)
    cls_val_dir = os.path.join(val_dir, cls)
    cls_test_dir = os.path.join(test_dir, cls)
    os.makedirs(cls_train_dir, exist_ok=True)
    os.makedirs(cls_val_dir, exist_ok=True)
    os.makedirs(cls_test_dir, exist_ok=True)

    # Get all image filenames 
    images = [f for f in os.listdir(cls_input_dir) if f.lower().endswith(('.jpg'))]

    # Shuffle the images to ensure random splits
    random.shuffle(images)

    total_count = len(images)
    test_count = int(0.2 * total_count)           # 20% for testing
    train_val_count = total_count - test_count      # Remaining 80% for training+validation

    # Now split training+validation into 90% training and 10% validation
    val_count = int(0.1 * train_val_count)          # 10% of 80%
    train_count = train_val_count - val_count       # 90% of 80%

    # Create the splits
    test_images = images[:test_count]
    train_val_images = images[test_count:]
    train_images = train_val_images[:train_count]
    val_images = train_val_images[train_count:]

    # Copy files to the respective directories
    for img in train_images:
        src = os.path.join(cls_input_dir, img)
        dst = os.path.join(cls_train_dir, img)
        shutil.copy2(src, dst)

    for img in val_images:
        src = os.path.join(cls_input_dir, img)
        dst = os.path.join(cls_val_dir, img)
        shutil.copy2(src, dst)

    for img in test_images:
        src = os.path.join(cls_input_dir, img)
        dst = os.path.join(cls_test_dir, img)
        shutil.copy2(src, dst)

    print(f"Class '{cls}': {len(train_images)} training, {len(val_images)} validation, {len(test_images)} testing images.")

print("Data splitting complete.")
# Out:
# Class 'bcc': 2160 training, 240 validation, 600 testing images.
# Class 'akiec': 2160 training, 240 validation, 600 testing images.
# Class 'nv': 2160 training, 240 validation, 600 testing images.
# Class 'bkl': 2160 training, 240 validation, 600 testing images.
# Class 'vasc': 2160 training, 240 validation, 600 testing images.
# Class 'mel': 2160 training, 240 validation, 600 testing images.
# Class 'df': 2160 training, 240 validation, 600 testing images.
# Data splitting complete.

# %%
import os

# Base directory where the split data is stored
base_dir = "/kaggle/working/HAM10000_split"

# Define the splits you have
splits = ["train", "val", "test"]

# Define the image file extensions to look for
image_extensions = ('.jpg')

for split in splits:
    split_dir = os.path.join(base_dir, split)
    print(f"Counts for {split}:")

    # Iterate over each class subfolder
    for cls in os.listdir(split_dir):
        cls_path = os.path.join(split_dir, cls)
        if os.path.isdir(cls_path):
            # Count files that have image extensions
            count = len([f for f in os.listdir(cls_path) if f.lower().endswith(image_extensions)])
            print(f"  {cls}: {count} images")
    print("-" * 40)
# Out:
# Counts for train:
#   bcc: 2160 images
#   akiec: 2160 images
#   nv: 2160 images
#   bkl: 2160 images
#   vasc: 2160 images
#   mel: 2160 images
#   df: 2160 images
# ----------------------------------------
# Counts for val:
#   bcc: 240 images
#   akiec: 240 images
#   nv: 240 images
#   bkl: 240 images
#   vasc: 240 images
#   mel: 240 images
#   df: 240 images
# ----------------------------------------
# Counts for test:
#   bcc: 600 images
#   akiec: 600 images
#   nv: 600 images
#   bkl: 600 images
#   vasc: 600 images
#   mel: 600 images
#   df: 600 images
# ----------------------------------------

# %%
import os
import numpy as np
from PIL import Image

# --- Paths & params ---
train_dir  = "/kaggle/working/HAM10000_split/train"
img_height = img_width = 224

# --- Compute mean & std on TRAIN set ---
channel_sum    = np.zeros(3, dtype=np.float64)
channel_sq_sum = np.zeros(3, dtype=np.float64)
pixel_count    = 0

for root, _, files in os.walk(train_dir):
    for fname in files:
        if not fname.lower().endswith((".jpg")):
            continue
        path = os.path.join(root, fname)
        img = Image.open(path).convert("RGB").resize((img_width, img_height))
        arr = np.asarray(img, dtype=np.float32) / 255.0
        channel_sum    += arr.sum(axis=(0,1))
        channel_sq_sum += (arr**2).sum(axis=(0,1))
        pixel_count    += img_width * img_height

mean = channel_sum / pixel_count
std  = np.sqrt(channel_sq_sum / pixel_count - mean**2)
print("Computed mean:", mean)
print("Computed std: ", std)

# --- Preprocessing function for ImageDataGenerator ---
def preprocess_fn(img):
    """
    img: HxWxC numpy array with values [0,255]
    Returns a float32 HxWxC array normalized by your computed mean/std.
    """
    img = img.astype(np.float32) / 255.0
    img = (img - mean) / std
    return img
# Out:
# Computed mean: [0.7943926  0.57079729 0.60930236]
# Computed std:  [0.14481409 0.16752706 0.18225199]

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.applications import EfficientNetB3
from tensorflow.keras.layers import Input, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# --- Mean and Std for Normalization (computed before) ---
mean = np.array([0.7943926,  0.57079729, 0.60930236], dtype=np.float32)
std  = np.array([[0.14481409, 0.16752706, 0.18225199]], dtype=np.float32)

# --- Paths & Params ---
base_dir    = "/kaggle/working/HAM10000_split"
train_dir   = os.path.join(base_dir, "train")
val_dir     = os.path.join(base_dir, "val")
test_dir    = os.path.join(base_dir, "test")
img_height  = img_width = 224  # EfficientNetB3 performs best at 300x300, but 224 is lighter
batch_size  = 32
num_classes = 7

# --- Preprocessing Function ---
def preprocess_fn(img):
    img = img.astype(np.float32) / 255.0
    img = (img - mean) / std
    return img

# --- Data Generators ---
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_fn,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)
val_test_datagen = ImageDataGenerator(preprocessing_function=preprocess_fn)

train_gen = train_datagen.flow_from_directory(
    train_dir, target_size=(img_height, img_width),
    batch_size=batch_size, class_mode='categorical', shuffle=True
)
val_gen = val_test_datagen.flow_from_directory(
    val_dir, target_size=(img_height, img_width),
    batch_size=batch_size, class_mode='categorical', shuffle=False
)
test_gen = val_test_datagen.flow_from_directory(
    test_dir, target_size=(img_height, img_width),
    batch_size=batch_size, class_mode='categorical', shuffle=False
)

# --- Build EfficientNetB3 Model ---
input_tensor = Input(shape=(img_height, img_width, 3))
base_model = EfficientNetB3(include_top=False, weights='imagenet', input_tensor=input_tensor)
x = base_model.output
x = MaxPooling2D(pool_size=(2, 2))(x)
x = Flatten()(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.5)(x)
output_tensor = Dense(num_classes, activation='softmax')(x)

model = Model(inputs=input_tensor, outputs=output_tensor)

# --- Compile ---
model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# --- Callbacks ---
checkpoint = ModelCheckpoint(
    filepath='/kaggle/working/efficientnetb3_model.h5',
    monitor='val_accuracy',
    save_best_only=True,
    verbose=1
)
earlystop = EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True,
    verbose=1
)

# --- Train ---
history = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=50,
    callbacks=[checkpoint, earlystop]
)

# --- Evaluate on test set ---
loss, acc = model.evaluate(test_gen)
print(f"Test loss: {loss:.4f}, Test accuracy: {acc:.4f}")

model.save('/kaggle/working/efficientnetb3.keras')
# Out:
# Found 15120 images belonging to 7 classes.
# Found 1680 images belonging to 7 classes.
# Found 4200 images belonging to 7 classes.
# Epoch 1/50
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 0s 469ms/step - accuracy: 0.3484 - loss: 1.7980
# Epoch 1: val_accuracy improved from -inf to 0.38333, saving model to /kaggle/working/efficientnetb3_model.h5
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 386s 518ms/step - accuracy: 0.3486 - loss: 1.7972 - val_accuracy: 0.3833 - val_loss: 1.7703
# Epoch 2/50
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.6588 - loss: 0.9070
# Epoch 2: val_accuracy improved from 0.38333 to 0.70952, saving model to /kaggle/working/efficientnetb3_model.h5
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 182s 383ms/step - accuracy: 0.6589 - loss: 0.9069 - val_accuracy: 0.7095 - val_loss: 0.7635
# Epoch 3/50
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.7468 - loss: 0.6962
# Epoch 3: val_accuracy improved from 0.70952 to 0.80298, saving model to /kaggle/working/efficientnetb3_model.h5
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 180s 381ms/step - accuracy: 0.7468 - loss: 0.6961 - val_accuracy: 0.8030 - val_loss: 0.4696
# Epoch 4/50
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.7901 - loss: 0.5630
# Epoch 4: val_accuracy did not improve from 0.80298
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 180s 379ms/step - accuracy: 0.7901 - loss: 0.5629 - val_accuracy: 0.7804 - val_loss: 0.5600
# Epoch 5/50
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.8309 - loss: 0.4622
# Epoch 5: val_accuracy did not improve from 0.80298
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 180s 380ms/step - accuracy: 0.8309 - loss: 0.4622 - val_accuracy: 0.6464 - val_loss: 1.1136
# Epoch 6/50
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step - accuracy: 0.8639 - loss: 0.3727
# Epoch 6: val_accuracy improved from 0.80298 to 0.87321, saving model to /kaggle/working/efficientnetb3_model.h5
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 182s 385ms/step - accuracy: 0.8639 - loss: 0.3727 - val_accuracy: 0.8732 - val_loss: 0.3290
# Epoch 7/50
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - accuracy: 0.8891 - loss: 0.3204
# Epoch 7: val_accuracy did not improve from 0.87321
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 178s 376ms/step - accuracy: 0.8891 - loss: 0.3204 - val_accuracy: 0.8726 - val_loss: 0.3685
# Epoch 8/50
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.9001 - loss: 0.2835
# Epoch 8: val_accuracy improved from 0.87321 to 0.90893, saving model to /kaggle/working/efficientnetb3_model.h5
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 181s 382ms/step - accuracy: 0.9001 - loss: 0.2835 - val_accuracy: 0.9089 - val_loss: 0.2524
# Epoch 9/50
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.9164 - loss: 0.2335
# Epoch 9: val_accuracy did not improve from 0.90893
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 179s 377ms/step - accuracy: 0.9164 - loss: 0.2335 - val_accuracy: 0.8196 - val_loss: 0.4918
# Epoch 10/50
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.9340 - loss: 0.1957
# Epoch 10: val_accuracy improved from 0.90893 to 0.91012, saving model to /kaggle/working/efficientnetb3_model.h5
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 180s 380ms/step - accuracy: 0.9340 - loss: 0.1957 - val_accuracy: 0.9101 - val_loss: 0.2518
# Epoch 11/50
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step - accuracy: 0.9371 - loss: 0.1808
# Epoch 11: val_accuracy did not improve from 0.91012
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 183s 385ms/step - accuracy: 0.9371 - loss: 0.1808 - val_accuracy: 0.8589 - val_loss: 0.4405
# Epoch 12/50
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.9504 - loss: 0.1527
# Epoch 12: val_accuracy improved from 0.91012 to 0.92202, saving model to /kaggle/working/efficientnetb3_model.h5
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 180s 380ms/step - accuracy: 0.9504 - loss: 0.1528 - val_accuracy: 0.9220 - val_loss: 0.2369
# Epoch 13/50
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.9490 - loss: 0.1495
# Epoch 13: val_accuracy improved from 0.92202 to 0.93690, saving model to /kaggle/working/efficientnetb3_model.h5
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 180s 380ms/step - accuracy: 0.9490 - loss: 0.1495 - val_accuracy: 0.9369 - val_loss: 0.1893
# Epoch 14/50
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - accuracy: 0.9573 - loss: 0.1294
# Epoch 14: val_accuracy did not improve from 0.93690
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 178s 375ms/step - accuracy: 0.9573 - loss: 0.1294 - val_accuracy: 0.9030 - val_loss: 0.3448
# Epoch 15/50
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.9637 - loss: 0.1025
# Epoch 15: val_accuracy did not improve from 0.93690
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 179s 378ms/step - accuracy: 0.9637 - loss: 0.1025 - val_accuracy: 0.9179 - val_loss: 0.3258
# Epoch 16/50
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - accuracy: 0.9633 - loss: 0.1052
# Epoch 16: val_accuracy did not improve from 0.93690
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 177s 374ms/step - accuracy: 0.9633 - loss: 0.1052 - val_accuracy: 0.7905 - val_loss: 0.8341
# Epoch 17/50
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.9678 - loss: 0.1010
# Epoch 17: val_accuracy did not improve from 0.93690
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 181s 381ms/step - accuracy: 0.9678 - loss: 0.1010 - val_accuracy: 0.8268 - val_loss: 0.6775
# Epoch 18/50
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - accuracy: 0.9703 - loss: 0.0921
# Epoch 18: val_accuracy did not improve from 0.93690
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 179s 379ms/step - accuracy: 0.9703 - loss: 0.0921 - val_accuracy: 0.9190 - val_loss: 0.2441
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 13.
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 15s 111ms/step - accuracy: 0.9508 - loss: 0.1401
# Test loss: 0.2087, Test accuracy: 0.9319

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import numpy as np

# --- 1. Plot training & validation accuracy/loss ---
plt.figure(figsize=(14, 5))

# Accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Acc', marker='o')
plt.plot(history.history['val_accuracy'], label='Val Acc', marker='o')
plt.title('Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

# Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss', marker='o')
plt.plot(history.history['val_loss'], label='Val Loss', marker='o')
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# --- Predict labels for test set ---
y_pred_probs = model.predict(test_gen)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = test_gen.classes

# --- Class names (in order of directory names) ---
class_names = list(test_gen.class_indices.keys())

# --- Confusion Matrix ---
cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap='Blues', xticks_rotation=45)
plt.title("Confusion Matrix")
plt.show()

# --- Classification Report ---
print("Classification Report:")
print(classification_report(y_true, y_pred, target_names=class_names))
# Out:
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 30s 151ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#        akiec       0.97      0.99      0.98       600
#          bcc       0.99      0.95      0.97       600
#          bkl       0.88      0.89      0.88       600
#           df       0.99      0.99      0.99       600
#          mel       0.91      0.81      0.85       600
#           nv       0.80      0.92      0.86       600
#         vasc       1.00      0.98      0.99       600
#
#     accuracy                           0.93      4200
#    macro avg       0.93      0.93      0.93      4200
# weighted avg       0.93      0.93      0.93      4200

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt

# --- Use the same mean and std used in training ---
mean = np.array([0.7943926,  0.57079729, 0.60930236], dtype=np.float32)
std  = np.array([0.14481409, 0.16752706, 0.18225199], dtype=np.float32)


# --- Define class names (update if needed) ---
class_names = ['akiec', 'bcc', 'bkl', 'df', 'mel', 'nv', 'vasc']

# --- Function to preprocess and predict ---
def predict_skin_disease(img_path, model):
    # Load image
    img = image.load_img(img_path, target_size=(224, 224))
    img_array = image.img_to_array(img)

    # Normalize
    img_array = img_array.astype(np.float32) / 255.0
    img_array = (img_array - mean) / std
    img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension

    # Predict
    preds = model.predict(img_array)
    pred_class = class_names[np.argmax(preds)]
    confidence = np.max(preds)

    # Show results
    plt.imshow(img)
    plt.axis('off')
    plt.title(f"Predicted: {pred_class} ({confidence:.2%} confidence)")
    plt.show()

    return pred_class, confidence

# --- Usage ---
img_path = '/kaggle/working/HAM10000_rearranged/akiec/ISIC_0024329.jpg'  # <-- Change to your image path
predict_skin_disease(img_path, model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 14s 14s/step
# ('akiec', 0.99929297)

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt

# --- Use the same mean and std used in training ---
mean = np.array([0.7943926,  0.57079729, 0.60930236], dtype=np.float32)
std  = np.array([0.14481409, 0.16752706, 0.18225199], dtype=np.float32)


# --- Define class names (update if needed) ---
class_names = ['akiec', 'bcc', 'bkl', 'df', 'mel', 'nv', 'vasc']

# --- Function to preprocess and predict ---
def predict_skin_disease(img_path, model):
    # Load image
    img = image.load_img(img_path, target_size=(224, 224))
    img_array = image.img_to_array(img)

    # Normalize
    img_array = img_array.astype(np.float32) / 255.0
    img_array = (img_array - mean) / std
    img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension

    # Predict
    preds = model.predict(img_array)
    pred_class = class_names[np.argmax(preds)]
    confidence = np.max(preds)

    # Show results
    plt.imshow(img)
    plt.axis('off')
    plt.title(f"Predicted: {pred_class} ({confidence:.2%} confidence)")
    plt.show()

    return pred_class, confidence

# --- Usage ---
img_path = '/kaggle/working/HAM10000_rearranged/bcc/ISIC_0024448.jpg'  # <-- Change to your image path
predict_skin_disease(img_path, model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ('bcc', 1.0)

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt

# --- Use the same mean and std used in training ---
mean = np.array([0.7943926,  0.57079729, 0.60930236], dtype=np.float32)
std  = np.array([0.14481409, 0.16752706, 0.18225199], dtype=np.float32)


# --- Define class names (update if needed) ---
class_names = ['akiec', 'bcc', 'bkl', 'df', 'mel', 'nv', 'vasc']

# --- Function to preprocess and predict ---
def predict_skin_disease(img_path, model):
    # Load image
    img = image.load_img(img_path, target_size=(224, 224))
    img_array = image.img_to_array(img)

    # Normalize
    img_array = img_array.astype(np.float32) / 255.0
    img_array = (img_array - mean) / std
    img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension

    # Predict
    preds = model.predict(img_array)
    pred_class = class_names[np.argmax(preds)]
    confidence = np.max(preds)

    # Show results
    plt.imshow(img)
    plt.axis('off')
    plt.title(f"Predicted: {pred_class} ({confidence:.2%} confidence)")
    plt.show()

    return pred_class, confidence

# --- Usage ---
img_path = '/kaggle/working/HAM10000_rearranged/bkl/ISIC_0024381.jpg'  # <-- Change to your image path
predict_skin_disease(img_path, model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# ('bkl', 0.9894029)

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt

# --- Use the same mean and std used in training ---
mean = np.array([0.7943926,  0.57079729, 0.60930236], dtype=np.float32)
std  = np.array([0.14481409, 0.16752706, 0.18225199], dtype=np.float32)


# --- Define class names (update if needed) ---
class_names = ['akiec', 'bcc', 'bkl', 'df', 'mel', 'nv', 'vasc']

# --- Function to preprocess and predict ---
def predict_skin_disease(img_path, model):
    # Load image
    img = image.load_img(img_path, target_size=(224, 224))
    img_array = image.img_to_array(img)

    # Normalize
    img_array = img_array.astype(np.float32) / 255.0
    img_array = (img_array - mean) / std
    img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension

    # Predict
    preds = model.predict(img_array)
    pred_class = class_names[np.argmax(preds)]
    confidence = np.max(preds)

    # Show results
    plt.imshow(img)
    plt.axis('off')
    plt.title(f"Predicted: {pred_class} ({confidence:.2%} confidence)")
    plt.show()

    return pred_class, confidence

# --- Usage ---
img_path = '/kaggle/working/HAM10000_rearranged/df/ISIC_0024994.jpg'  # <-- Change to your image path
predict_skin_disease(img_path, model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ('df', 0.99981064)

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt

# --- Use the same mean and std used in training ---
mean = np.array([0.7943926,  0.57079729, 0.60930236], dtype=np.float32)
std  = np.array([0.14481409, 0.16752706, 0.18225199], dtype=np.float32)


# --- Define class names (update if needed) ---
class_names = ['akiec', 'bcc', 'bkl', 'df', 'mel', 'nv', 'vasc']

# --- Function to preprocess and predict ---
def predict_skin_disease(img_path, model):
    # Load image
    img = image.load_img(img_path, target_size=(224, 224))
    img_array = image.img_to_array(img)

    # Normalize
    img_array = img_array.astype(np.float32) / 255.0
    img_array = (img_array - mean) / std
    img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension

    # Predict
    preds = model.predict(img_array)
    pred_class = class_names[np.argmax(preds)]
    confidence = np.max(preds)

    # Show results
    plt.imshow(img)
    plt.axis('off')
    plt.title(f"Predicted: {pred_class} ({confidence:.2%} confidence)")
    plt.show()

    return pred_class, confidence

# --- Usage ---
img_path = '/kaggle/working/HAM10000_rearranged/mel/ISIC_0024482.jpg'  # <-- Change to your image path
predict_skin_disease(img_path, model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ('mel', 0.9102134)

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt

# --- Use the same mean and std used in training ---
mean = np.array([0.7943926,  0.57079729, 0.60930236], dtype=np.float32)
std  = np.array([0.14481409, 0.16752706, 0.18225199], dtype=np.float32)


# --- Define class names (update if needed) ---
class_names = ['akiec', 'bcc', 'bkl', 'df', 'mel', 'nv', 'vasc']

# --- Function to preprocess and predict ---
def predict_skin_disease(img_path, model):
    # Load image
    img = image.load_img(img_path, target_size=(224, 224))
    img_array = image.img_to_array(img)

    # Normalize
    img_array = img_array.astype(np.float32) / 255.0
    img_array = (img_array - mean) / std
    img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension

    # Predict
    preds = model.predict(img_array)
    pred_class = class_names[np.argmax(preds)]
    confidence = np.max(preds)

    # Show results
    plt.imshow(img)
    plt.axis('off')
    plt.title(f"Predicted: {pred_class} ({confidence:.2%} confidence)")
    plt.show()

    return pred_class, confidence

# --- Usage ---
img_path = '/kaggle/working/HAM10000_rearranged/nv/ISIC_0024317.jpg'  # <-- Change to your image path
predict_skin_disease(img_path, model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ('nv', 0.9933193)

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt

# --- Use the same mean and std used in training ---
mean = np.array([0.7943926,  0.57079729, 0.60930236], dtype=np.float32)
std  = np.array([0.14481409, 0.16752706, 0.18225199], dtype=np.float32)


# --- Define class names (update if needed) ---
class_names = ['akiec', 'bcc', 'bkl', 'df', 'mel', 'nv', 'vasc']

# --- Function to preprocess and predict ---
def predict_skin_disease(img_path, model):
    # Load image
    img = image.load_img(img_path, target_size=(224, 224))
    img_array = image.img_to_array(img)

    # Normalize
    img_array = img_array.astype(np.float32) / 255.0
    img_array = (img_array - mean) / std
    img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension

    # Predict
    preds = model.predict(img_array)
    pred_class = class_names[np.argmax(preds)]
    confidence = np.max(preds)

    # Show results
    plt.imshow(img)
    plt.axis('off')
    plt.title(f"Predicted: {pred_class} ({confidence:.2%} confidence)")
    plt.show()

    return pred_class, confidence

# --- Usage ---
img_path = '/kaggle/working/HAM10000_split/test/vasc/ISIC_0024370_aug20.jpg'  # <-- Change to your image path
predict_skin_disease(img_path, model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# ('vasc', 1.0)

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import Input, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# --- Mean and Std for Normalization (computed before) ---
mean = np.array([0.7943926,  0.57079729, 0.60930236], dtype=np.float32)
std  = np.array([0.14481409, 0.16752706, 0.18225199], dtype=np.float32)

# --- Paths & Params ---
base_dir    = "/kaggle/working/HAM10000_split"
train_dir   = os.path.join(base_dir, "train")
val_dir     = os.path.join(base_dir, "val")
test_dir    = os.path.join(base_dir, "test")
img_height  = img_width = 224  # ResNet50 prefers 224x224
batch_size  = 32
num_classes = 7

# --- Preprocessing Function ---
def preprocess_fn(img):
    img = img.astype(np.float32) / 255.0
    img = (img - mean) / std
    return img

# --- Data Generators ---
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_fn,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)
val_test_datagen = ImageDataGenerator(preprocessing_function=preprocess_fn)

train_gen = train_datagen.flow_from_directory(
    train_dir, target_size=(img_height, img_width),
    batch_size=batch_size, class_mode='categorical', shuffle=True
)
val_gen = val_test_datagen.flow_from_directory(
    val_dir, target_size=(img_height, img_width),
    batch_size=batch_size, class_mode='categorical', shuffle=False
)
test_gen = val_test_datagen.flow_from_directory(
    test_dir, target_size=(img_height, img_width),
    batch_size=batch_size, class_mode='categorical', shuffle=False
)

# --- Build ResNet50 Model ---
input_tensor = Input(shape=(img_height, img_width, 3))
base_model = ResNet50(include_top=False, weights='imagenet', input_tensor=input_tensor)
x = base_model.output
x = MaxPooling2D(pool_size=(2, 2))(x)
x = Flatten()(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.5)(x)
output_tensor = Dense(num_classes, activation='softmax')(x)

model = Model(inputs=input_tensor, outputs=output_tensor)

# --- Compile ---
model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# --- Callbacks ---
checkpoint = ModelCheckpoint(
    filepath='/kaggle/working/HAM10000_resnet50_model.h5',
    monitor='val_accuracy',
    save_best_only=True,
    verbose=1
)
earlystop = EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True,
    verbose=1
)

# --- Train ---
history = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=50,
    callbacks=[checkpoint, earlystop]
)

# --- Evaluate on test set ---
loss, acc = model.evaluate(test_gen)
print(f"Test loss: {loss:.4f}, Test accuracy: {acc:.4f}")
# Out:
# Found 15120 images belonging to 7 classes.
# Found 1680 images belonging to 7 classes.
# Found 4200 images belonging to 7 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 0s 438ms/step - accuracy: 0.3395 - loss: 2.0416
# Epoch 1: val_accuracy improved from -inf to 0.16369, saving model to /kaggle/working/HAM10000_resnet50_model.h5
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 305s 467ms/step - accuracy: 0.3397 - loss: 2.0405 - val_accuracy: 0.1637 - val_loss: 4.3289
# Epoch 2/50
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step - accuracy: 0.6059 - loss: 1.0535
# Epoch 2: val_accuracy improved from 0.16369 to 0.72202, saving model to /kaggle/working/HAM10000_resnet50_model.h5
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 189s 398ms/step - accuracy: 0.6060 - loss: 1.0533 - val_accuracy: 0.7220 - val_loss: 0.7190
# Epoch 3/50
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step - accuracy: 0.7029 - loss: 0.8223
# Epoch 3: val_accuracy improved from 0.72202 to 0.77083, saving model to /kaggle/working/HAM10000_resnet50_model.h5
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 187s 395ms/step - accuracy: 0.7030 - loss: 0.8222 - val_accuracy: 0.7708 - val_loss: 0.6103
# Epoch 4/50
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step - accuracy: 0.7606 - loss: 0.6747
# Epoch 4: val_accuracy improved from 0.77083 to 0.77202, saving model to /kaggle/working/HAM10000_resnet50_model.h5
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 186s 393ms/step - accuracy: 0.7606 - loss: 0.6747 - val_accuracy: 0.7720 - val_loss: 0.6175
# Epoch 5/50
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step - accuracy: 0.7839 - loss: 0.5990
# Epoch 5: val_accuracy improved from 0.77202 to 0.79583, saving model to /kaggle/working/HAM10000_resnet50_model.h5
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 189s 398ms/step - accuracy: 0.7839 - loss: 0.5990 - val_accuracy: 0.7958 - val_loss: 0.5406
# Epoch 6/50
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step - accuracy: 0.8064 - loss: 0.5446
# Epoch 6: val_accuracy improved from 0.79583 to 0.83988, saving model to /kaggle/working/HAM10000_resnet50_model.h5
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 188s 397ms/step - accuracy: 0.8064 - loss: 0.5446 - val_accuracy: 0.8399 - val_loss: 0.4256
# Epoch 7/50
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step - accuracy: 0.8251 - loss: 0.4758
# Epoch 7: val_accuracy did not improve from 0.83988
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 195s 412ms/step - accuracy: 0.8251 - loss: 0.4758 - val_accuracy: 0.8244 - val_loss: 0.4392
# Epoch 8/50
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step - accuracy: 0.8406 - loss: 0.4473
# Epoch 8: val_accuracy did not improve from 0.83988
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 189s 399ms/step - accuracy: 0.8406 - loss: 0.4473 - val_accuracy: 0.8327 - val_loss: 0.4493
# Epoch 9/50
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - accuracy: 0.8665 - loss: 0.3861
# Epoch 9: val_accuracy improved from 0.83988 to 0.85238, saving model to /kaggle/working/HAM10000_resnet50_model.h5
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 196s 413ms/step - accuracy: 0.8665 - loss: 0.3862 - val_accuracy: 0.8524 - val_loss: 0.3945
# Epoch 10/50
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step - accuracy: 0.8738 - loss: 0.3590
# Epoch 10: val_accuracy did not improve from 0.85238
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 187s 394ms/step - accuracy: 0.8738 - loss: 0.3590 - val_accuracy: 0.8083 - val_loss: 0.5360
# Epoch 11/50
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step - accuracy: 0.8830 - loss: 0.3361
# Epoch 11: val_accuracy improved from 0.85238 to 0.86190, saving model to /kaggle/working/HAM10000_resnet50_model.h5
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 187s 395ms/step - accuracy: 0.8829 - loss: 0.3361 - val_accuracy: 0.8619 - val_loss: 0.3994
# Epoch 12/50
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step - accuracy: 0.8946 - loss: 0.3052
# Epoch 12: val_accuracy improved from 0.86190 to 0.87262, saving model to /kaggle/working/HAM10000_resnet50_model.h5
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 197s 416ms/step - accuracy: 0.8946 - loss: 0.3052 - val_accuracy: 0.8726 - val_loss: 0.3272
# Epoch 13/50
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step - accuracy: 0.8944 - loss: 0.2904
# Epoch 13: val_accuracy did not improve from 0.87262
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 186s 393ms/step - accuracy: 0.8944 - loss: 0.2904 - val_accuracy: 0.8571 - val_loss: 0.4211
# Epoch 14/50
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step - accuracy: 0.9081 - loss: 0.2688
# Epoch 14: val_accuracy improved from 0.87262 to 0.89643, saving model to /kaggle/working/HAM10000_resnet50_model.h5
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 192s 405ms/step - accuracy: 0.9081 - loss: 0.2688 - val_accuracy: 0.8964 - val_loss: 0.2669
# Epoch 15/50
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step - accuracy: 0.9193 - loss: 0.2420
# Epoch 15: val_accuracy did not improve from 0.89643
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 195s 412ms/step - accuracy: 0.9193 - loss: 0.2420 - val_accuracy: 0.8470 - val_loss: 0.4463
# Epoch 16/50
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - accuracy: 0.9236 - loss: 0.2306
# Epoch 16: val_accuracy did not improve from 0.89643
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 195s 410ms/step - accuracy: 0.9236 - loss: 0.2306 - val_accuracy: 0.8940 - val_loss: 0.3043
# Epoch 17/50
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 0s 393ms/step - accuracy: 0.9349 - loss: 0.1860
# Epoch 17: val_accuracy did not improve from 0.89643
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 192s 405ms/step - accuracy: 0.9349 - loss: 0.1860 - val_accuracy: 0.8911 - val_loss: 0.2929
# Epoch 18/50
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 0s 395ms/step - accuracy: 0.9314 - loss: 0.2186
# Epoch 18: val_accuracy improved from 0.89643 to 0.90893, saving model to /kaggle/working/HAM10000_resnet50_model.h5
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 194s 410ms/step - accuracy: 0.9314 - loss: 0.2186 - val_accuracy: 0.9089 - val_loss: 0.2668
# Epoch 19/50
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - accuracy: 0.9409 - loss: 0.1803
# Epoch 19: val_accuracy improved from 0.90893 to 0.91845, saving model to /kaggle/working/HAM10000_resnet50_model.h5
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 195s 412ms/step - accuracy: 0.9409 - loss: 0.1803 - val_accuracy: 0.9185 - val_loss: 0.2854
# Epoch 20/50
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 0s 393ms/step - accuracy: 0.9414 - loss: 0.1829
# Epoch 20: val_accuracy improved from 0.91845 to 0.92440, saving model to /kaggle/working/HAM10000_resnet50_model.h5
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 193s 408ms/step - accuracy: 0.9414 - loss: 0.1829 - val_accuracy: 0.9244 - val_loss: 0.2308
# Epoch 21/50
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step - accuracy: 0.9460 - loss: 0.1616
# Epoch 21: val_accuracy did not improve from 0.92440
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 188s 397ms/step - accuracy: 0.9460 - loss: 0.1616 - val_accuracy: 0.9208 - val_loss: 0.2756
# Epoch 22/50
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step - accuracy: 0.9521 - loss: 0.1392
# Epoch 22: val_accuracy did not improve from 0.92440
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 187s 395ms/step - accuracy: 0.9521 - loss: 0.1392 - val_accuracy: 0.8911 - val_loss: 0.3230
# Epoch 23/50
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - accuracy: 0.9501 - loss: 0.1490
# Epoch 23: val_accuracy improved from 0.92440 to 0.93333, saving model to /kaggle/working/HAM10000_resnet50_model.h5
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 196s 414ms/step - accuracy: 0.9501 - loss: 0.1490 - val_accuracy: 0.9333 - val_loss: 0.2081
# Epoch 24/50
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 0s 421ms/step - accuracy: 0.9516 - loss: 0.1328
# Epoch 24: val_accuracy did not improve from 0.93333
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 205s 433ms/step - accuracy: 0.9516 - loss: 0.1328 - val_accuracy: 0.9125 - val_loss: 0.2689
# Epoch 25/50
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step - accuracy: 0.9472 - loss: 0.1740
# Epoch 25: val_accuracy did not improve from 0.93333
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 198s 417ms/step - accuracy: 0.9472 - loss: 0.1740 - val_accuracy: 0.9298 - val_loss: 0.2231
# Epoch 26/50
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step - accuracy: 0.9582 - loss: 0.1222
# Epoch 26: val_accuracy improved from 0.93333 to 0.93988, saving model to /kaggle/working/HAM10000_resnet50_model.h5
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 201s 424ms/step - accuracy: 0.9582 - loss: 0.1222 - val_accuracy: 0.9399 - val_loss: 0.2262
# Epoch 27/50
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step - accuracy: 0.9610 - loss: 0.1160
# Epoch 27: val_accuracy did not improve from 0.93988
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 199s 420ms/step - accuracy: 0.9610 - loss: 0.1160 - val_accuracy: 0.9244 - val_loss: 0.2432
# Epoch 28/50
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step - accuracy: 0.9640 - loss: 0.1121
# Epoch 28: val_accuracy did not improve from 0.93988
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 202s 426ms/step - accuracy: 0.9640 - loss: 0.1121 - val_accuracy: 0.9083 - val_loss: 0.4512
# Epoch 28: early stopping
# Restoring model weights from the end of the best epoch: 23.
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 16s 124ms/step - accuracy: 0.9502 - loss: 0.1620
# Test loss: 0.2039, Test accuracy: 0.9381

# %%
model.save('/kaggle/working/resnet50.keras')

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import numpy as np

# --- 1. Plot training & validation accuracy/loss ---
plt.figure(figsize=(14, 5))

# Accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Acc', marker='o')
plt.plot(history.history['val_accuracy'], label='Val Acc', marker='o')
plt.title('Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

# Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss', marker='o')
plt.plot(history.history['val_loss'], label='Val Loss', marker='o')
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# --- Predict labels for test set ---
y_pred_probs = model.predict(test_gen)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = test_gen.classes

# --- Class names (in order of directory names) ---
class_names = list(test_gen.class_indices.keys())

# --- Confusion Matrix ---
cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap='Blues', xticks_rotation=45)
plt.title("Confusion Matrix")
plt.show()

# --- Classification Report ---
print("Classification Report:")
print(classification_report(y_true, y_pred, target_names=class_names))
# Out:
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 25s 134ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#        akiec       0.97      0.98      0.97       600
#          bcc       0.97      0.97      0.97       600
#          bkl       0.92      0.85      0.89       600
#           df       0.99      0.99      0.99       600
#          mel       0.90      0.82      0.86       600
#           nv       0.83      0.95      0.88       600
#         vasc       1.00      1.00      1.00       600
#
#     accuracy                           0.94      4200
#    macro avg       0.94      0.94      0.94      4200
# weighted avg       0.94      0.94      0.94      4200

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt

# --- Use the same mean and std used in training ---
mean = np.array([0.7943926,  0.57079729, 0.60930236], dtype=np.float32)
std  = np.array([0.14481409, 0.16752706, 0.18225199], dtype=np.float32)


# --- Define class names (update if needed) ---
class_names = ['akiec', 'bcc', 'bkl', 'df', 'mel', 'nv', 'vasc']

# --- Function to preprocess and predict ---
def predict_skin_disease(img_path, model):
    # Load image
    img = image.load_img(img_path, target_size=(224, 224))
    img_array = image.img_to_array(img)

    # Normalize
    img_array = img_array.astype(np.float32) / 255.0
    img_array = (img_array - mean) / std
    img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension

    # Predict
    preds = model.predict(img_array)
    pred_class = class_names[np.argmax(preds)]
    confidence = np.max(preds)

    # Show results
    plt.imshow(img)
    plt.axis('off')
    plt.title(f"Predicted: {pred_class} ({confidence:.2%} confidence)")
    plt.show()

    return pred_class, confidence

# --- Usage ---
img_path = '/kaggle/working/HAM10000_rearranged/akiec/ISIC_0024329.jpg'  # <-- Change to your image path
predict_skin_disease(img_path, model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step
# ('akiec', 0.9982437)

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt

# --- Use the same mean and std used in training ---
mean = np.array([0.7943926,  0.57079729, 0.60930236], dtype=np.float32)
std  = np.array([0.14481409, 0.16752706, 0.18225199], dtype=np.float32)


# --- Define class names (update if needed) ---
class_names = ['akiec', 'bcc', 'bkl', 'df', 'mel', 'nv', 'vasc']

# --- Function to preprocess and predict ---
def predict_skin_disease(img_path, model):
    # Load image
    img = image.load_img(img_path, target_size=(224, 224))
    img_array = image.img_to_array(img)

    # Normalize
    img_array = img_array.astype(np.float32) / 255.0
    img_array = (img_array - mean) / std
    img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension

    # Predict
    preds = model.predict(img_array)
    pred_class = class_names[np.argmax(preds)]
    confidence = np.max(preds)

    # Show results
    plt.imshow(img)
    plt.axis('off')
    plt.title(f"Predicted: {pred_class} ({confidence:.2%} confidence)")
    plt.show()

    return pred_class, confidence

# --- Usage ---
img_path = '/kaggle/working/HAM10000_rearranged/df/ISIC_0026254.jpg'  # <-- Change to your image path
predict_skin_disease(img_path, model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# ('df', 0.9453164)

# %%
import os
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import Adam

# --- Directory Paths ---
base_dir    = "/kaggle/working/HAM10000_split"  
train_dir   = os.path.join(base_dir, "train")
val_dir     = os.path.join(base_dir, "val")
test_dir    = os.path.join(base_dir, "test")

# --- Constants ---
img_height  = img_width = 128
batch_size  = 32
num_classes = 7
epochs      = 50

# --- Image Generators ---
train_gen = ImageDataGenerator().flow_from_directory(
    train_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True
)

val_gen = ImageDataGenerator().flow_from_directory(
    val_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)

test_gen = ImageDataGenerator().flow_from_directory(
    test_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)

# --- Custom CNN Architecture ---
input_tensor = Input(shape=(img_height, img_width, 3))

x = Conv2D(32, (3, 3), activation='relu', padding='same')(input_tensor)
x = BatchNormalization()(x)
x = MaxPooling2D(pool_size=(2, 2))(x)

x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D(pool_size=(2, 2))(x)

x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D(pool_size=(2, 2))(x)

x = GlobalAveragePooling2D()(x)
x = Dropout(0.5)(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.3)(x)

output_tensor = Dense(num_classes, activation='softmax')(x)

model = Model(inputs=input_tensor, outputs=output_tensor)

# --- Compile ---
model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# --- Callbacks ---
checkpoint = ModelCheckpoint(
    filepath='custom_cnn_model.h5',
    monitor='val_accuracy',
    save_best_only=True,
    verbose=1
)
earlystop = EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True,
    verbose=1
)

# --- Train ---
history = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=epochs,
    callbacks=[checkpoint, earlystop]
)

# --- Evaluate ---
loss, acc = model.evaluate(test_gen)
print(f"Test loss: {loss:.4f}, Test accuracy: {acc:.4f}")
# Out:
# Found 15120 images belonging to 7 classes.
# Found 1680 images belonging to 7 classes.
# Found 4200 images belonging to 7 classes.
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.2551 - loss: 1.9303
# Epoch 1: val_accuracy improved from -inf to 0.39702, saving model to custom_cnn_model.h5
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 25s 35ms/step - accuracy: 0.2552 - loss: 1.9300 - val_accuracy: 0.3970 - val_loss: 1.5539
# Epoch 2/50
# 472/473 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.3829 - loss: 1.5947
# Epoch 2: val_accuracy improved from 0.39702 to 0.46071, saving model to custom_cnn_model.h5
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 11s 22ms/step - accuracy: 0.3829 - loss: 1.5946 - val_accuracy: 0.4607 - val_loss: 1.3992
# Epoch 3/50
# 472/473 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.4255 - loss: 1.4808
# Epoch 3: val_accuracy did not improve from 0.46071
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - accuracy: 0.4255 - loss: 1.4807 - val_accuracy: 0.4202 - val_loss: 1.4530
# Epoch 4/50
# 472/473 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.4564 - loss: 1.4170
# Epoch 4: val_accuracy did not improve from 0.46071
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.4565 - loss: 1.4169 - val_accuracy: 0.4464 - val_loss: 1.4016
# Epoch 5/50
# 472/473 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.4708 - loss: 1.3704
# Epoch 5: val_accuracy improved from 0.46071 to 0.48036, saving model to custom_cnn_model.h5
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 11s 22ms/step - accuracy: 0.4708 - loss: 1.3703 - val_accuracy: 0.4804 - val_loss: 1.3330
# Epoch 6/50
# 472/473 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.4856 - loss: 1.3273
# Epoch 6: val_accuracy improved from 0.48036 to 0.52619, saving model to custom_cnn_model.h5
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.4856 - loss: 1.3273 - val_accuracy: 0.5262 - val_loss: 1.2210
# Epoch 7/50
# 472/473 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.4914 - loss: 1.3069
# Epoch 7: val_accuracy did not improve from 0.52619
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.4914 - loss: 1.3068 - val_accuracy: 0.4833 - val_loss: 1.3512
# Epoch 8/50
# 472/473 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.4997 - loss: 1.2849
# Epoch 8: val_accuracy did not improve from 0.52619
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - accuracy: 0.4997 - loss: 1.2848 - val_accuracy: 0.4946 - val_loss: 1.3190
# Epoch 9/50
# 471/473 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5149 - loss: 1.2521
# Epoch 9: val_accuracy did not improve from 0.52619
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 11s 22ms/step - accuracy: 0.5149 - loss: 1.2521 - val_accuracy: 0.5042 - val_loss: 1.3495
# Epoch 10/50
# 472/473 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5195 - loss: 1.2455
# Epoch 10: val_accuracy improved from 0.52619 to 0.56488, saving model to custom_cnn_model.h5
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 11s 22ms/step - accuracy: 0.5196 - loss: 1.2454 - val_accuracy: 0.5649 - val_loss: 1.1068
# Epoch 11/50
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5426 - loss: 1.2028
# Epoch 11: val_accuracy did not improve from 0.56488
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.5426 - loss: 1.2028 - val_accuracy: 0.5458 - val_loss: 1.1458
# Epoch 12/50
# 472/473 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5295 - loss: 1.1913
# Epoch 12: val_accuracy improved from 0.56488 to 0.58571, saving model to custom_cnn_model.h5
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.5295 - loss: 1.1913 - val_accuracy: 0.5857 - val_loss: 1.0711
# Epoch 13/50
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5490 - loss: 1.1611
# Epoch 13: val_accuracy did not improve from 0.58571
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - accuracy: 0.5490 - loss: 1.1611 - val_accuracy: 0.5750 - val_loss: 1.0658
# Epoch 14/50
# 472/473 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5601 - loss: 1.1429
# Epoch 14: val_accuracy did not improve from 0.58571
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.5601 - loss: 1.1429 - val_accuracy: 0.5155 - val_loss: 1.2259
# Epoch 15/50
# 472/473 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5538 - loss: 1.1490
# Epoch 15: val_accuracy improved from 0.58571 to 0.60060, saving model to custom_cnn_model.h5
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.5538 - loss: 1.1490 - val_accuracy: 0.6006 - val_loss: 1.0394
# Epoch 16/50
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5729 - loss: 1.1103
# Epoch 16: val_accuracy did not improve from 0.60060
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.5729 - loss: 1.1103 - val_accuracy: 0.5964 - val_loss: 1.0509
# Epoch 17/50
# 472/473 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5763 - loss: 1.0976
# Epoch 17: val_accuracy did not improve from 0.60060
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.5763 - loss: 1.0976 - val_accuracy: 0.5298 - val_loss: 1.2499
# Epoch 18/50
# 471/473 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5757 - loss: 1.0955
# Epoch 18: val_accuracy improved from 0.60060 to 0.62679, saving model to custom_cnn_model.h5
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 11s 22ms/step - accuracy: 0.5757 - loss: 1.0954 - val_accuracy: 0.6268 - val_loss: 0.9736
# Epoch 19/50
# 472/473 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5825 - loss: 1.0696
# Epoch 19: val_accuracy did not improve from 0.62679
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.5826 - loss: 1.0696 - val_accuracy: 0.5476 - val_loss: 1.2337
# Epoch 20/50
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5880 - loss: 1.0642
# Epoch 20: val_accuracy did not improve from 0.62679
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.5880 - loss: 1.0642 - val_accuracy: 0.6000 - val_loss: 0.9998
# Epoch 21/50
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5967 - loss: 1.0417
# Epoch 21: val_accuracy improved from 0.62679 to 0.63214, saving model to custom_cnn_model.h5
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.5967 - loss: 1.0417 - val_accuracy: 0.6321 - val_loss: 0.9648
# Epoch 22/50
# 472/473 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6006 - loss: 1.0404
# Epoch 22: val_accuracy improved from 0.63214 to 0.64405, saving model to custom_cnn_model.h5
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.6006 - loss: 1.0404 - val_accuracy: 0.6440 - val_loss: 0.9226
# Epoch 23/50
# 471/473 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6060 - loss: 1.0147
# Epoch 23: val_accuracy did not improve from 0.64405
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.6059 - loss: 1.0147 - val_accuracy: 0.5958 - val_loss: 1.0288
# Epoch 24/50
# 471/473 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6092 - loss: 1.0189
# Epoch 24: val_accuracy did not improve from 0.64405
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 11s 22ms/step - accuracy: 0.6092 - loss: 1.0189 - val_accuracy: 0.6369 - val_loss: 0.9255
# Epoch 25/50
# 471/473 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6128 - loss: 1.0096
# Epoch 25: val_accuracy did not improve from 0.64405
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.6128 - loss: 1.0095 - val_accuracy: 0.6238 - val_loss: 0.9572
# Epoch 26/50
# 472/473 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6171 - loss: 0.9924
# Epoch 26: val_accuracy did not improve from 0.64405
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.6171 - loss: 0.9924 - val_accuracy: 0.6167 - val_loss: 0.9874
# Epoch 27/50
# 472/473 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6333 - loss: 0.9632
# Epoch 27: val_accuracy improved from 0.64405 to 0.66310, saving model to custom_cnn_model.h5
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.6333 - loss: 0.9633 - val_accuracy: 0.6631 - val_loss: 0.8631
# Epoch 28/50
# 471/473 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6312 - loss: 0.9648
# Epoch 28: val_accuracy did not improve from 0.66310
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.6312 - loss: 0.9648 - val_accuracy: 0.6423 - val_loss: 0.9376
# Epoch 29/50
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6455 - loss: 0.9435
# Epoch 29: val_accuracy did not improve from 0.66310
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.6455 - loss: 0.9435 - val_accuracy: 0.6542 - val_loss: 0.8992
# Epoch 30/50
# 472/473 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6429 - loss: 0.9405
# Epoch 30: val_accuracy improved from 0.66310 to 0.66369, saving model to custom_cnn_model.h5
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - accuracy: 0.6429 - loss: 0.9405 - val_accuracy: 0.6637 - val_loss: 0.8677
# Epoch 31/50
# 472/473 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6369 - loss: 0.9356
# Epoch 31: val_accuracy improved from 0.66369 to 0.66726, saving model to custom_cnn_model.h5
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.6369 - loss: 0.9356 - val_accuracy: 0.6673 - val_loss: 0.8519
# Epoch 32/50
# 472/473 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6475 - loss: 0.9186
# Epoch 32: val_accuracy did not improve from 0.66726
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.6475 - loss: 0.9187 - val_accuracy: 0.6548 - val_loss: 0.9237
# Epoch 33/50
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6516 - loss: 0.9216
# Epoch 33: val_accuracy improved from 0.66726 to 0.68274, saving model to custom_cnn_model.h5
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.6516 - loss: 0.9216 - val_accuracy: 0.6827 - val_loss: 0.8337
# Epoch 34/50
# 472/473 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6571 - loss: 0.8979
# Epoch 34: val_accuracy did not improve from 0.68274
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.6571 - loss: 0.8979 - val_accuracy: 0.6494 - val_loss: 0.8961
# Epoch 35/50
# 472/473 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6561 - loss: 0.8961
# Epoch 35: val_accuracy did not improve from 0.68274
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 11s 22ms/step - accuracy: 0.6561 - loss: 0.8961 - val_accuracy: 0.6429 - val_loss: 0.9168
# Epoch 36/50
# 472/473 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6627 - loss: 0.8885
# Epoch 36: val_accuracy improved from 0.68274 to 0.69286, saving model to custom_cnn_model.h5
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 11s 22ms/step - accuracy: 0.6627 - loss: 0.8885 - val_accuracy: 0.6929 - val_loss: 0.7931
# Epoch 37/50
# 472/473 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6663 - loss: 0.8745
# Epoch 37: val_accuracy did not improve from 0.69286
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.6663 - loss: 0.8745 - val_accuracy: 0.6083 - val_loss: 1.0550
# Epoch 38/50
# 472/473 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6702 - loss: 0.8693
# Epoch 38: val_accuracy did not improve from 0.69286
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - accuracy: 0.6702 - loss: 0.8693 - val_accuracy: 0.6560 - val_loss: 0.8881
# Epoch 39/50
# 471/473 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6708 - loss: 0.8570
# Epoch 39: val_accuracy improved from 0.69286 to 0.70893, saving model to custom_cnn_model.h5
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - accuracy: 0.6708 - loss: 0.8570 - val_accuracy: 0.7089 - val_loss: 0.7593
# Epoch 40/50
# 471/473 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6813 - loss: 0.8405
# Epoch 40: val_accuracy did not improve from 0.70893
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 11s 22ms/step - accuracy: 0.6813 - loss: 0.8406 - val_accuracy: 0.6988 - val_loss: 0.7925
# Epoch 41/50
# 472/473 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6888 - loss: 0.8245
# Epoch 41: val_accuracy did not improve from 0.70893
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.6887 - loss: 0.8246 - val_accuracy: 0.7054 - val_loss: 0.7707
# Epoch 42/50
# 471/473 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6870 - loss: 0.8263
# Epoch 42: val_accuracy did not improve from 0.70893
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - accuracy: 0.6870 - loss: 0.8263 - val_accuracy: 0.6976 - val_loss: 0.8118
# Epoch 43/50
# 472/473 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6776 - loss: 0.8382
# Epoch 43: val_accuracy did not improve from 0.70893
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 11s 22ms/step - accuracy: 0.6777 - loss: 0.8382 - val_accuracy: 0.6958 - val_loss: 0.7961
# Epoch 44/50
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6945 - loss: 0.8070
# Epoch 44: val_accuracy did not improve from 0.70893
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.6945 - loss: 0.8070 - val_accuracy: 0.6917 - val_loss: 0.7937
# Epoch 44: early stopping
# Restoring model weights from the end of the best epoch: 39.
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.6661 - loss: 0.8788
# Test loss: 0.7656, Test accuracy: 0.7067

# %%
model.save('/kaggle/working/cnn.keras')

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import numpy as np

# --- 1. Plot training & validation accuracy/loss ---
plt.figure(figsize=(14, 5))

# Accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Acc', marker='o')
plt.plot(history.history['val_accuracy'], label='Val Acc', marker='o')
plt.title('Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

# Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss', marker='o')
plt.plot(history.history['val_loss'], label='Val Loss', marker='o')
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# --- Predict labels for test set ---
y_pred_probs = model.predict(test_gen)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = test_gen.classes

# --- Class names (in order of directory names) ---
class_names = list(test_gen.class_indices.keys())

# --- Confusion Matrix ---
cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap='Blues', xticks_rotation=45)
plt.title("Confusion Matrix")
plt.show()

# --- Classification Report ---
print("Classification Report:")
print(classification_report(y_true, y_pred, target_names=class_names))
# Out:
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#        akiec       0.54      0.69      0.61       600
#          bcc       0.64      0.70      0.67       600
#          bkl       0.56      0.45      0.50       600
#           df       0.79      0.78      0.78       600
#          mel       0.65      0.62      0.63       600
#           nv       0.85      0.72      0.78       600
#         vasc       0.96      0.98      0.97       600
#
#     accuracy                           0.71      4200
#    macro avg       0.71      0.71      0.71      4200
# weighted avg       0.71      0.71      0.71      4200
